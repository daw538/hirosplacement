# %%
import numpy as np
import pandas as pd
from IPython import display
import matplotlib.pyplot as plot
import glob
import pystan

# Defines preview options
pd.options.display.max_rows = 10
pd.options.display.float_format = '{:.3f}'.format

# %%
#colnames=['voltage', 'value', 'nan'] # Change to whatever you want
files=glob.glob('C:/Users/Emma/Summer_Project/Data/temperature_scan/180725cooling/*.csv')

len(files) #28 for full set, 14 for each line

# Prints statistics of file
#display.display(test.describe())
# Prints csv preview
#display.display(test)
# Out:
# 28

# %%
fig=plot.figure()

for fl in files:
    data=pd.read_csv(fl, sep=';')
    plot.plot(data['Piezo Voltage (V)'], data['Fine In 1 (V)'])
plot.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import pystan
model_code = 'parameters {real y;} model {y ~ normal(0,1);}'
model = pystan.StanModel(model_code=model_code)
y = model.sampling(n_jobs=1).extract()['y']
y.mean()  # with luck the result will be near 0
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_5944b02c79788fa0db5b3a93728ca2bf NOW.
# ---------------------------------------------------------------------------
# DistutilsPlatformError                    Traceback (most recent call last)
# <ipython-input-5-4fcf970c114c> in <module>()
#       1 import pystan
#       2 model_code = 'parameters {real y;} model {y ~ normal(0,1);}'
# ----> 3 model = pystan.StanModel(model_code=model_code)
#       4 y = model.sampling(n_jobs=1).extract()['y']
#       5 y.mean()  # with luck the result will be near 0
#
# ~\Anaconda3\lib\site-packages\pystan\model.py in __init__(self, file, charset, model_name, model_code, stanc_ret, boost_lib, eigen_lib, verbose, obfuscate_model_name, extra_compile_args)
#     311
#     312         try:
# --> 313             build_extension.run()
#     314         finally:
#     315             if redirect_stderr:
#
# ~\Anaconda3\lib\distutils\command\build_ext.py in run(self)
#     337
# ...

# %%
import emcee
emcee.test()
# Out:
# Starting tests...
# test_blobs ...
#     Passed.
# test_ensemble ...
#     Passed.
# test_inf_nan_params ...
#     Passed.
# test_mh ...
#     Passed.
# test_nan_lnprob ...
#     Passed.
# test_parallel ...
#     Passed.
# test_pt_sampler ...
# [[18.19518584 17.30162136 16.49384519 11.2211846  22.79507818]
#  [ 7.01224826  8.80215329  7.87396434  7.57204728  8.36566108]
#  [ 3.22943192  2.98984572  2.37108469  1.45019094  2.64603631]
#  [ 2.50140518  1.86158933  1.58021024  1.06191038  1.4577418 ]
#  [ 2.03389903  1.84197767  1.62430825  1.26734853  1.58201526]
#  [ 2.03063762  1.83791534  1.69758273  1.40456905  1.51399557]
#  [ 1.89962826  1.82385556  1.7142237   1.33989858  1.5494746 ]
#  [ 1.95477556  2.02669484  1.74145659  1.35177892  1.70761723]
#  [ 1.97827568  2.0120248   1.75544392  1.45917641  1.66612768]
#  [ 1.98065675  1.9634434   1.78481548  1.41330857  1.63561976]
#  [ 2.05181952  2.09300777  1.76703544  1.40021749  1.71587408]
# ...
