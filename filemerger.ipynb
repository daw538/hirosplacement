# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
# %matplotlib inline

# %%
files = glob.glob('/home/daniel/Documents/hirosplacement/Data/*.txt')


n = [i for i in files]
data = [np.genfromtxt(n, delimiter=';') for n in files[:50]]
#print(data[0])
#q = (np.asarray(data))
#print(q.shape)
#print(q)
#r = q.transpose([1,0,2]).reshape(3648,100).T
#r = np.delete(r, list(range(2, r.shape[1], 2)), axis=0)
#print(r.shape)
#print(r)



#plt.plot(data[0][0,:])
#plt.plot(data[0][:,0], data[0][:,1], 'k.')
print(data[0][2000,1])
print(np.mean(data[0][2000:2100,1]))


#for d in data:
#    plt.plot(d[:,0], d[:,1])
      

for idx, _ in enumerate(data):
    data[idx][:,1] /= np.mean(data[idx][2000:2100,1])
    plt.plot(data[idx][:,0], data[idx][:,1])
# Out:
# 0.1091188118
# 0.13350631907600002

# %%
print(len(files))
# Out:
# 7569
